# %%
# !pip install --upgrade git+https://github.com/sovrasov/flops-counter.pytorch.git
# Out:
# Collecting git+https://github.com/sovrasov/flops-counter.pytorch.git
#   Cloning https://github.com/sovrasov/flops-counter.pytorch.git to /tmp/pip-req-build-2hadtp0j
#   Running command git clone --filter=blob:none --quiet https://github.com/sovrasov/flops-counter.pytorch.git /tmp/pip-req-build-2hadtp0j
#   Resolved https://github.com/sovrasov/flops-counter.pytorch.git to commit b5c9ef779a02c5fd4e611a20dba31548fdc8e69b
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from ptflops==0.7.1.2) (2.1.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->ptflops==0.7.1.2) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->ptflops==0.7.1.2) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->ptflops==0.7.1.2) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->ptflops==0.7.1.2) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->ptflops==0.7.1.2) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->ptflops==0.7.1.2) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->ptflops==0.7.1.2) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->ptflops==0.7.1.2) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->ptflops==0.7.1.2) (1.3.0)

# %%
# !pip install pretrained-backbones-unet
# Out:
# Requirement already satisfied: pretrained-backbones-unet in /usr/local/lib/python3.10/dist-packages (0.0.1)
# Requirement already satisfied: timm==0.6.12 in /usr/local/lib/python3.10/dist-packages (from pretrained-backbones-unet) (0.6.12)
# Requirement already satisfied: torch>=1.13.1 in /usr/local/lib/python3.10/dist-packages (from pretrained-backbones-unet) (2.1.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm==0.6.12->pretrained-backbones-unet) (0.16.0+cu118)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm==0.6.12->pretrained-backbones-unet) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from timm==0.6.12->pretrained-backbones-unet) (0.19.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.1->pretrained-backbones-unet) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.1->pretrained-backbones-unet) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.1->pretrained-backbones-unet) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.1->pretrained-backbones-unet) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.1->pretrained-backbones-unet) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.1->pretrained-backbones-unet) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.1->pretrained-backbones-unet) (2.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm==0.6.12->pretrained-backbones-unet) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm==0.6.12->pretrained-backbones-unet) (4.66.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm==0.6.12->pretrained-backbones-unet) (23.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.1->pretrained-backbones-unet) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13.1->pretrained-backbones-unet) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->timm==0.6.12->pretrained-backbones-unet) (1.23.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm==0.6.12->pretrained-backbones-unet) (9.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm==0.6.12->pretrained-backbones-unet) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm==0.6.12->pretrained-backbones-unet) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm==0.6.12->pretrained-backbones-unet) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm==0.6.12->pretrained-backbones-unet) (2023.11.17)

# %%
import torchvision.models as models
import torch
from ptflops import get_model_complexity_info
from backbones_unet.model.unet import Unet

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# convnext parmas, macs 측정
with torch.cuda.device(0):
  net = models.convnext_small(weights=None)

  macs, params = get_model_complexity_info(net, (3, 224, 224), as_strings=True,
                                           print_per_layer_stat=True, verbose=True)
  print('{:<30}  {:<8}'.format('Computational complexity: ', macs))
  print('{:<30}  {:<8}'.format('Number of parameters: ', params))
# Out:
# Warning: module LayerNorm2d is treated as a zero-op.
# Warning: module Conv2dNormActivation is treated as a zero-op.
# Warning: module Permute is treated as a zero-op.
# Warning: module StochasticDepth is treated as a zero-op.
# Warning: module CNBlock is treated as a zero-op.
# Warning: module Flatten is treated as a zero-op.
# Warning: module ConvNeXt is treated as a zero-op.
# ConvNeXt(
#   50.21 M, 99.967% Params, 8.71 GMac, 99.839% MACs,
#   (features): Sequential(
#     49.44 M, 98.436% Params, 8.7 GMac, 99.830% MACs,
#     (0): Conv2dNormActivation(
#       4.7 k, 0.009% Params, 14.75 MMac, 0.169% MACs,
#       (0): Conv2d(4.7 k, 0.009% Params, 14.75 MMac, 0.169% MACs, 3, 96, kernel_size=(4, 4), stride=(4, 4))
#       (1): LayerNorm2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (96,), eps=1e-06, elementwise_affine=True)
#     )
#     (1): Sequential(
#       237.6 k, 0.473% Params, 743.31 MMac, 8.525% MACs,
#       (0): CNBlock(
#         79.2 k, 0.158% Params, 247.77 MMac, 2.842% MACs,
#         (block): Sequential(
#           79.2 k, 0.158% Params, 247.77 MMac, 2.842% MACs,
#           (0): Conv2d(4.8 k, 0.010% Params, 15.05 MMac, 0.173% MACs, 96, 96, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=96)
#           (1): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (2): LayerNorm(192, 0.000% Params, 301.06 KMac, 0.003% MACs, (96,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(37.25 k, 0.074% Params, 115.61 MMac, 1.326% MACs, in_features=96, out_features=384, bias=True)
#           (4): GELU(0, 0.000% Params, 1.2 MMac, 0.014% MACs, approximate='none')
#           (5): Linear(36.96 k, 0.074% Params, 115.61 MMac, 1.326% MACs, in_features=384, out_features=96, bias=True)
#           (6): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#       )
#       (1): CNBlock(
#         79.2 k, 0.158% Params, 247.77 MMac, 2.842% MACs,
#         (block): Sequential(
#           79.2 k, 0.158% Params, 247.77 MMac, 2.842% MACs,
#           (0): Conv2d(4.8 k, 0.010% Params, 15.05 MMac, 0.173% MACs, 96, 96, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=96)
#           (1): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (2): LayerNorm(192, 0.000% Params, 301.06 KMac, 0.003% MACs, (96,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(37.25 k, 0.074% Params, 115.61 MMac, 1.326% MACs, in_features=96, out_features=384, bias=True)
#           (4): GELU(0, 0.000% Params, 1.2 MMac, 0.014% MACs, approximate='none')
#           (5): Linear(36.96 k, 0.074% Params, 115.61 MMac, 1.326% MACs, in_features=384, out_features=96, bias=True)
#           (6): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (stochastic_depth): StochasticDepth(p=0.011428571428571429, mode=row)
#       )
#       (2): CNBlock(
#         79.2 k, 0.158% Params, 247.77 MMac, 2.842% MACs,
#         (block): Sequential(
#           79.2 k, 0.158% Params, 247.77 MMac, 2.842% MACs,
#           (0): Conv2d(4.8 k, 0.010% Params, 15.05 MMac, 0.173% MACs, 96, 96, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=96)
#           (1): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (2): LayerNorm(192, 0.000% Params, 301.06 KMac, 0.003% MACs, (96,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(37.25 k, 0.074% Params, 115.61 MMac, 1.326% MACs, in_features=96, out_features=384, bias=True)
#           (4): GELU(0, 0.000% Params, 1.2 MMac, 0.014% MACs, approximate='none')
#           (5): Linear(36.96 k, 0.074% Params, 115.61 MMac, 1.326% MACs, in_features=384, out_features=96, bias=True)
#           (6): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (stochastic_depth): StochasticDepth(p=0.022857142857142857, mode=row)
#       )
#     )
#     (2): Sequential(
#       73.92 k, 0.147% Params, 57.95 MMac, 0.665% MACs,
#       (0): LayerNorm2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (96,), eps=1e-06, elementwise_affine=True)
#       (1): Conv2d(73.92 k, 0.147% Params, 57.95 MMac, 0.665% MACs, 96, 192, kernel_size=(2, 2), stride=(2, 2))
#     )
#     (3): Sequential(
#       917.57 k, 1.827% Params, 718.47 MMac, 8.240% MACs,
#       (0): CNBlock(
#         305.86 k, 0.609% Params, 239.49 MMac, 2.747% MACs,
#         (block): Sequential(
#           305.86 k, 0.609% Params, 239.49 MMac, 2.747% MACs,
#           (0): Conv2d(9.6 k, 0.019% Params, 7.53 MMac, 0.086% MACs, 192, 192, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=192)
#           (1): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (2): LayerNorm(384, 0.001% Params, 150.53 KMac, 0.002% MACs, (192,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(148.22 k, 0.295% Params, 115.61 MMac, 1.326% MACs, in_features=192, out_features=768, bias=True)
#           (4): GELU(0, 0.000% Params, 602.11 KMac, 0.007% MACs, approximate='none')
#           (5): Linear(147.65 k, 0.294% Params, 115.61 MMac, 1.326% MACs, in_features=768, out_features=192, bias=True)
#           (6): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (stochastic_depth): StochasticDepth(p=0.03428571428571429, mode=row)
#       )
#       (1): CNBlock(
#         305.86 k, 0.609% Params, 239.49 MMac, 2.747% MACs,
#         (block): Sequential(
#           305.86 k, 0.609% Params, 239.49 MMac, 2.747% MACs,
#           (0): Conv2d(9.6 k, 0.019% Params, 7.53 MMac, 0.086% MACs, 192, 192, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=192)
#           (1): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (2): LayerNorm(384, 0.001% Params, 150.53 KMac, 0.002% MACs, (192,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(148.22 k, 0.295% Params, 115.61 MMac, 1.326% MACs, in_features=192, out_features=768, bias=True)
#           (4): GELU(0, 0.000% Params, 602.11 KMac, 0.007% MACs, approximate='none')
#           (5): Linear(147.65 k, 0.294% Params, 115.61 MMac, 1.326% MACs, in_features=768, out_features=192, bias=True)
#           (6): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (stochastic_depth): StochasticDepth(p=0.045714285714285714, mode=row)
#       )
#       (2): CNBlock(
#         305.86 k, 0.609% Params, 239.49 MMac, 2.747% MACs,
#         (block): Sequential(
#           305.86 k, 0.609% Params, 239.49 MMac, 2.747% MACs,
#           (0): Conv2d(9.6 k, 0.019% Params, 7.53 MMac, 0.086% MACs, 192, 192, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=192)
#           (1): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (2): LayerNorm(384, 0.001% Params, 150.53 KMac, 0.002% MACs, (192,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(148.22 k, 0.295% Params, 115.61 MMac, 1.326% MACs, in_features=192, out_features=768, bias=True)
#           (4): GELU(0, 0.000% Params, 602.11 KMac, 0.007% MACs, approximate='none')
#           (5): Linear(147.65 k, 0.294% Params, 115.61 MMac, 1.326% MACs, in_features=768, out_features=192, bias=True)
#           (6): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05714285714285714, mode=row)
#       )
#     )
#     (4): Sequential(
#       295.3 k, 0.588% Params, 57.88 MMac, 0.664% MACs,
#       (0): LayerNorm2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (192,), eps=1e-06, elementwise_affine=True)
#       (1): Conv2d(295.3 k, 0.588% Params, 57.88 MMac, 0.664% MACs, 192, 384, kernel_size=(2, 2), stride=(2, 2))
#     )
#     (5): Sequential(
#       32.44 M, 64.594% Params, 6.35 GMac, 72.878% MACs,
#       (0): CNBlock(
#         1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#         (block): Sequential(
#           1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#           (0): Conv2d(19.2 k, 0.038% Params, 3.76 MMac, 0.043% MACs, 384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (2): LayerNorm(768, 0.002% Params, 75.26 KMac, 0.001% MACs, (384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(591.36 k, 1.177% Params, 115.61 MMac, 1.326% MACs, in_features=384, out_features=1536, bias=True)
#           (4): GELU(0, 0.000% Params, 301.06 KMac, 0.003% MACs, approximate='none')
#           (5): Linear(590.21 k, 1.175% Params, 115.61 MMac, 1.326% MACs, in_features=1536, out_features=384, bias=True)
#           (6): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (stochastic_depth): StochasticDepth(p=0.06857142857142857, mode=row)
#       )
#       (1): CNBlock(
#         1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#         (block): Sequential(
#           1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#           (0): Conv2d(19.2 k, 0.038% Params, 3.76 MMac, 0.043% MACs, 384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (2): LayerNorm(768, 0.002% Params, 75.26 KMac, 0.001% MACs, (384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(591.36 k, 1.177% Params, 115.61 MMac, 1.326% MACs, in_features=384, out_features=1536, bias=True)
#           (4): GELU(0, 0.000% Params, 301.06 KMac, 0.003% MACs, approximate='none')
#           (5): Linear(590.21 k, 1.175% Params, 115.61 MMac, 1.326% MACs, in_features=1536, out_features=384, bias=True)
#           (6): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08, mode=row)
#       )
#       (2): CNBlock(
#         1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#         (block): Sequential(
#           1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#           (0): Conv2d(19.2 k, 0.038% Params, 3.76 MMac, 0.043% MACs, 384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (2): LayerNorm(768, 0.002% Params, 75.26 KMac, 0.001% MACs, (384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(591.36 k, 1.177% Params, 115.61 MMac, 1.326% MACs, in_features=384, out_features=1536, bias=True)
#           (4): GELU(0, 0.000% Params, 301.06 KMac, 0.003% MACs, approximate='none')
#           (5): Linear(590.21 k, 1.175% Params, 115.61 MMac, 1.326% MACs, in_features=1536, out_features=384, bias=True)
#           (6): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (stochastic_depth): StochasticDepth(p=0.09142857142857143, mode=row)
#       )
#       (3): CNBlock(
#         1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#         (block): Sequential(
#           1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#           (0): Conv2d(19.2 k, 0.038% Params, 3.76 MMac, 0.043% MACs, 384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (2): LayerNorm(768, 0.002% Params, 75.26 KMac, 0.001% MACs, (384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(591.36 k, 1.177% Params, 115.61 MMac, 1.326% MACs, in_features=384, out_features=1536, bias=True)
#           (4): GELU(0, 0.000% Params, 301.06 KMac, 0.003% MACs, approximate='none')
#           (5): Linear(590.21 k, 1.175% Params, 115.61 MMac, 1.326% MACs, in_features=1536, out_features=384, bias=True)
#           (6): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (stochastic_depth): StochasticDepth(p=0.10285714285714286, mode=row)
#       )
#       (4): CNBlock(
#         1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#         (block): Sequential(
#           1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#           (0): Conv2d(19.2 k, 0.038% Params, 3.76 MMac, 0.043% MACs, 384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (2): LayerNorm(768, 0.002% Params, 75.26 KMac, 0.001% MACs, (384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(591.36 k, 1.177% Params, 115.61 MMac, 1.326% MACs, in_features=384, out_features=1536, bias=True)
#           (4): GELU(0, 0.000% Params, 301.06 KMac, 0.003% MACs, approximate='none')
#           (5): Linear(590.21 k, 1.175% Params, 115.61 MMac, 1.326% MACs, in_features=1536, out_features=384, bias=True)
#           (6): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (stochastic_depth): StochasticDepth(p=0.11428571428571428, mode=row)
#       )
#       (5): CNBlock(
#         1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#         (block): Sequential(
#           1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#           (0): Conv2d(19.2 k, 0.038% Params, 3.76 MMac, 0.043% MACs, 384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (2): LayerNorm(768, 0.002% Params, 75.26 KMac, 0.001% MACs, (384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(591.36 k, 1.177% Params, 115.61 MMac, 1.326% MACs, in_features=384, out_features=1536, bias=True)
#           (4): GELU(0, 0.000% Params, 301.06 KMac, 0.003% MACs, approximate='none')
#           (5): Linear(590.21 k, 1.175% Params, 115.61 MMac, 1.326% MACs, in_features=1536, out_features=384, bias=True)
#           (6): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (stochastic_depth): StochasticDepth(p=0.12571428571428572, mode=row)
#       )
#       (6): CNBlock(
#         1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#         (block): Sequential(
#           1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#           (0): Conv2d(19.2 k, 0.038% Params, 3.76 MMac, 0.043% MACs, 384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (2): LayerNorm(768, 0.002% Params, 75.26 KMac, 0.001% MACs, (384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(591.36 k, 1.177% Params, 115.61 MMac, 1.326% MACs, in_features=384, out_features=1536, bias=True)
#           (4): GELU(0, 0.000% Params, 301.06 KMac, 0.003% MACs, approximate='none')
#           (5): Linear(590.21 k, 1.175% Params, 115.61 MMac, 1.326% MACs, in_features=1536, out_features=384, bias=True)
#           (6): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (stochastic_depth): StochasticDepth(p=0.13714285714285715, mode=row)
#       )
#       (7): CNBlock(
#         1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#         (block): Sequential(
#           1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#           (0): Conv2d(19.2 k, 0.038% Params, 3.76 MMac, 0.043% MACs, 384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (2): LayerNorm(768, 0.002% Params, 75.26 KMac, 0.001% MACs, (384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(591.36 k, 1.177% Params, 115.61 MMac, 1.326% MACs, in_features=384, out_features=1536, bias=True)
#           (4): GELU(0, 0.000% Params, 301.06 KMac, 0.003% MACs, approximate='none')
#           (5): Linear(590.21 k, 1.175% Params, 115.61 MMac, 1.326% MACs, in_features=1536, out_features=384, bias=True)
#           (6): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (stochastic_depth): StochasticDepth(p=0.14857142857142858, mode=row)
#       )
#       (8): CNBlock(
#         1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#         (block): Sequential(
#           1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#           (0): Conv2d(19.2 k, 0.038% Params, 3.76 MMac, 0.043% MACs, 384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (2): LayerNorm(768, 0.002% Params, 75.26 KMac, 0.001% MACs, (384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(591.36 k, 1.177% Params, 115.61 MMac, 1.326% MACs, in_features=384, out_features=1536, bias=True)
#           (4): GELU(0, 0.000% Params, 301.06 KMac, 0.003% MACs, approximate='none')
#           (5): Linear(590.21 k, 1.175% Params, 115.61 MMac, 1.326% MACs, in_features=1536, out_features=384, bias=True)
#           (6): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (stochastic_depth): StochasticDepth(p=0.16, mode=row)
#       )
#       (9): CNBlock(
#         1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#         (block): Sequential(
#           1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#           (0): Conv2d(19.2 k, 0.038% Params, 3.76 MMac, 0.043% MACs, 384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (2): LayerNorm(768, 0.002% Params, 75.26 KMac, 0.001% MACs, (384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(591.36 k, 1.177% Params, 115.61 MMac, 1.326% MACs, in_features=384, out_features=1536, bias=True)
#           (4): GELU(0, 0.000% Params, 301.06 KMac, 0.003% MACs, approximate='none')
#           (5): Linear(590.21 k, 1.175% Params, 115.61 MMac, 1.326% MACs, in_features=1536, out_features=384, bias=True)
#           (6): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17142857142857143, mode=row)
#       )
#       (10): CNBlock(
#         1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#         (block): Sequential(
#           1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#           (0): Conv2d(19.2 k, 0.038% Params, 3.76 MMac, 0.043% MACs, 384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (2): LayerNorm(768, 0.002% Params, 75.26 KMac, 0.001% MACs, (384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(591.36 k, 1.177% Params, 115.61 MMac, 1.326% MACs, in_features=384, out_features=1536, bias=True)
#           (4): GELU(0, 0.000% Params, 301.06 KMac, 0.003% MACs, approximate='none')
#           (5): Linear(590.21 k, 1.175% Params, 115.61 MMac, 1.326% MACs, in_features=1536, out_features=384, bias=True)
#           (6): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (stochastic_depth): StochasticDepth(p=0.18285714285714286, mode=row)
#       )
#       (11): CNBlock(
#         1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#         (block): Sequential(
#           1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#           (0): Conv2d(19.2 k, 0.038% Params, 3.76 MMac, 0.043% MACs, 384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (2): LayerNorm(768, 0.002% Params, 75.26 KMac, 0.001% MACs, (384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(591.36 k, 1.177% Params, 115.61 MMac, 1.326% MACs, in_features=384, out_features=1536, bias=True)
#           (4): GELU(0, 0.000% Params, 301.06 KMac, 0.003% MACs, approximate='none')
#           (5): Linear(590.21 k, 1.175% Params, 115.61 MMac, 1.326% MACs, in_features=1536, out_features=384, bias=True)
#           (6): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1942857142857143, mode=row)
#       )
#       (12): CNBlock(
#         1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#         (block): Sequential(
#           1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#           (0): Conv2d(19.2 k, 0.038% Params, 3.76 MMac, 0.043% MACs, 384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (2): LayerNorm(768, 0.002% Params, 75.26 KMac, 0.001% MACs, (384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(591.36 k, 1.177% Params, 115.61 MMac, 1.326% MACs, in_features=384, out_features=1536, bias=True)
#           (4): GELU(0, 0.000% Params, 301.06 KMac, 0.003% MACs, approximate='none')
#           (5): Linear(590.21 k, 1.175% Params, 115.61 MMac, 1.326% MACs, in_features=1536, out_features=384, bias=True)
#           (6): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (stochastic_depth): StochasticDepth(p=0.2057142857142857, mode=row)
#       )
#       (13): CNBlock(
#         1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#         (block): Sequential(
#           1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#           (0): Conv2d(19.2 k, 0.038% Params, 3.76 MMac, 0.043% MACs, 384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (2): LayerNorm(768, 0.002% Params, 75.26 KMac, 0.001% MACs, (384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(591.36 k, 1.177% Params, 115.61 MMac, 1.326% MACs, in_features=384, out_features=1536, bias=True)
#           (4): GELU(0, 0.000% Params, 301.06 KMac, 0.003% MACs, approximate='none')
#           (5): Linear(590.21 k, 1.175% Params, 115.61 MMac, 1.326% MACs, in_features=1536, out_features=384, bias=True)
#           (6): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (stochastic_depth): StochasticDepth(p=0.21714285714285717, mode=row)
#       )
#       (14): CNBlock(
#         1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#         (block): Sequential(
#           1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#           (0): Conv2d(19.2 k, 0.038% Params, 3.76 MMac, 0.043% MACs, 384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (2): LayerNorm(768, 0.002% Params, 75.26 KMac, 0.001% MACs, (384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(591.36 k, 1.177% Params, 115.61 MMac, 1.326% MACs, in_features=384, out_features=1536, bias=True)
#           (4): GELU(0, 0.000% Params, 301.06 KMac, 0.003% MACs, approximate='none')
#           (5): Linear(590.21 k, 1.175% Params, 115.61 MMac, 1.326% MACs, in_features=1536, out_features=384, bias=True)
#           (6): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (stochastic_depth): StochasticDepth(p=0.22857142857142856, mode=row)
#       )
#       (15): CNBlock(
#         1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#         (block): Sequential(
#           1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#           (0): Conv2d(19.2 k, 0.038% Params, 3.76 MMac, 0.043% MACs, 384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (2): LayerNorm(768, 0.002% Params, 75.26 KMac, 0.001% MACs, (384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(591.36 k, 1.177% Params, 115.61 MMac, 1.326% MACs, in_features=384, out_features=1536, bias=True)
#           (4): GELU(0, 0.000% Params, 301.06 KMac, 0.003% MACs, approximate='none')
#           (5): Linear(590.21 k, 1.175% Params, 115.61 MMac, 1.326% MACs, in_features=1536, out_features=384, bias=True)
#           (6): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (stochastic_depth): StochasticDepth(p=0.24000000000000002, mode=row)
#       )
#       (16): CNBlock(
#         1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#         (block): Sequential(
#           1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#           (0): Conv2d(19.2 k, 0.038% Params, 3.76 MMac, 0.043% MACs, 384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (2): LayerNorm(768, 0.002% Params, 75.26 KMac, 0.001% MACs, (384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(591.36 k, 1.177% Params, 115.61 MMac, 1.326% MACs, in_features=384, out_features=1536, bias=True)
#           (4): GELU(0, 0.000% Params, 301.06 KMac, 0.003% MACs, approximate='none')
#           (5): Linear(590.21 k, 1.175% Params, 115.61 MMac, 1.326% MACs, in_features=1536, out_features=384, bias=True)
#           (6): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (stochastic_depth): StochasticDepth(p=0.25142857142857145, mode=row)
#       )
#       (17): CNBlock(
#         1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#         (block): Sequential(
#           1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#           (0): Conv2d(19.2 k, 0.038% Params, 3.76 MMac, 0.043% MACs, 384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (2): LayerNorm(768, 0.002% Params, 75.26 KMac, 0.001% MACs, (384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(591.36 k, 1.177% Params, 115.61 MMac, 1.326% MACs, in_features=384, out_features=1536, bias=True)
#           (4): GELU(0, 0.000% Params, 301.06 KMac, 0.003% MACs, approximate='none')
#           (5): Linear(590.21 k, 1.175% Params, 115.61 MMac, 1.326% MACs, in_features=1536, out_features=384, bias=True)
#           (6): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (stochastic_depth): StochasticDepth(p=0.2628571428571429, mode=row)
#       )
#       (18): CNBlock(
#         1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#         (block): Sequential(
#           1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#           (0): Conv2d(19.2 k, 0.038% Params, 3.76 MMac, 0.043% MACs, 384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (2): LayerNorm(768, 0.002% Params, 75.26 KMac, 0.001% MACs, (384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(591.36 k, 1.177% Params, 115.61 MMac, 1.326% MACs, in_features=384, out_features=1536, bias=True)
#           (4): GELU(0, 0.000% Params, 301.06 KMac, 0.003% MACs, approximate='none')
#           (5): Linear(590.21 k, 1.175% Params, 115.61 MMac, 1.326% MACs, in_features=1536, out_features=384, bias=True)
#           (6): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (stochastic_depth): StochasticDepth(p=0.2742857142857143, mode=row)
#       )
#       (19): CNBlock(
#         1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#         (block): Sequential(
#           1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#           (0): Conv2d(19.2 k, 0.038% Params, 3.76 MMac, 0.043% MACs, 384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (2): LayerNorm(768, 0.002% Params, 75.26 KMac, 0.001% MACs, (384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(591.36 k, 1.177% Params, 115.61 MMac, 1.326% MACs, in_features=384, out_features=1536, bias=True)
#           (4): GELU(0, 0.000% Params, 301.06 KMac, 0.003% MACs, approximate='none')
#           (5): Linear(590.21 k, 1.175% Params, 115.61 MMac, 1.326% MACs, in_features=1536, out_features=384, bias=True)
#           (6): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (stochastic_depth): StochasticDepth(p=0.2857142857142857, mode=row)
#       )
#       (20): CNBlock(
#         1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#         (block): Sequential(
#           1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#           (0): Conv2d(19.2 k, 0.038% Params, 3.76 MMac, 0.043% MACs, 384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (2): LayerNorm(768, 0.002% Params, 75.26 KMac, 0.001% MACs, (384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(591.36 k, 1.177% Params, 115.61 MMac, 1.326% MACs, in_features=384, out_features=1536, bias=True)
#           (4): GELU(0, 0.000% Params, 301.06 KMac, 0.003% MACs, approximate='none')
#           (5): Linear(590.21 k, 1.175% Params, 115.61 MMac, 1.326% MACs, in_features=1536, out_features=384, bias=True)
#           (6): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (stochastic_depth): StochasticDepth(p=0.29714285714285715, mode=row)
#       )
#       (21): CNBlock(
#         1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#         (block): Sequential(
#           1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#           (0): Conv2d(19.2 k, 0.038% Params, 3.76 MMac, 0.043% MACs, 384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (2): LayerNorm(768, 0.002% Params, 75.26 KMac, 0.001% MACs, (384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(591.36 k, 1.177% Params, 115.61 MMac, 1.326% MACs, in_features=384, out_features=1536, bias=True)
#           (4): GELU(0, 0.000% Params, 301.06 KMac, 0.003% MACs, approximate='none')
#           (5): Linear(590.21 k, 1.175% Params, 115.61 MMac, 1.326% MACs, in_features=1536, out_features=384, bias=True)
#           (6): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (stochastic_depth): StochasticDepth(p=0.3085714285714286, mode=row)
#       )
#       (22): CNBlock(
#         1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#         (block): Sequential(
#           1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#           (0): Conv2d(19.2 k, 0.038% Params, 3.76 MMac, 0.043% MACs, 384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (2): LayerNorm(768, 0.002% Params, 75.26 KMac, 0.001% MACs, (384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(591.36 k, 1.177% Params, 115.61 MMac, 1.326% MACs, in_features=384, out_features=1536, bias=True)
#           (4): GELU(0, 0.000% Params, 301.06 KMac, 0.003% MACs, approximate='none')
#           (5): Linear(590.21 k, 1.175% Params, 115.61 MMac, 1.326% MACs, in_features=1536, out_features=384, bias=True)
#           (6): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (stochastic_depth): StochasticDepth(p=0.32, mode=row)
#       )
#       (23): CNBlock(
#         1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#         (block): Sequential(
#           1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#           (0): Conv2d(19.2 k, 0.038% Params, 3.76 MMac, 0.043% MACs, 384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (2): LayerNorm(768, 0.002% Params, 75.26 KMac, 0.001% MACs, (384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(591.36 k, 1.177% Params, 115.61 MMac, 1.326% MACs, in_features=384, out_features=1536, bias=True)
#           (4): GELU(0, 0.000% Params, 301.06 KMac, 0.003% MACs, approximate='none')
#           (5): Linear(590.21 k, 1.175% Params, 115.61 MMac, 1.326% MACs, in_features=1536, out_features=384, bias=True)
#           (6): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (stochastic_depth): StochasticDepth(p=0.33142857142857146, mode=row)
#       )
#       (24): CNBlock(
#         1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#         (block): Sequential(
#           1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#           (0): Conv2d(19.2 k, 0.038% Params, 3.76 MMac, 0.043% MACs, 384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (2): LayerNorm(768, 0.002% Params, 75.26 KMac, 0.001% MACs, (384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(591.36 k, 1.177% Params, 115.61 MMac, 1.326% MACs, in_features=384, out_features=1536, bias=True)
#           (4): GELU(0, 0.000% Params, 301.06 KMac, 0.003% MACs, approximate='none')
#           (5): Linear(590.21 k, 1.175% Params, 115.61 MMac, 1.326% MACs, in_features=1536, out_features=384, bias=True)
#           (6): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (stochastic_depth): StochasticDepth(p=0.34285714285714286, mode=row)
#       )
#       (25): CNBlock(
#         1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#         (block): Sequential(
#           1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#           (0): Conv2d(19.2 k, 0.038% Params, 3.76 MMac, 0.043% MACs, 384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (2): LayerNorm(768, 0.002% Params, 75.26 KMac, 0.001% MACs, (384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(591.36 k, 1.177% Params, 115.61 MMac, 1.326% MACs, in_features=384, out_features=1536, bias=True)
#           (4): GELU(0, 0.000% Params, 301.06 KMac, 0.003% MACs, approximate='none')
#           (5): Linear(590.21 k, 1.175% Params, 115.61 MMac, 1.326% MACs, in_features=1536, out_features=384, bias=True)
#           (6): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (stochastic_depth): StochasticDepth(p=0.3542857142857143, mode=row)
#       )
#       (26): CNBlock(
#         1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#         (block): Sequential(
#           1.2 M, 2.392% Params, 235.35 MMac, 2.699% MACs,
#           (0): Conv2d(19.2 k, 0.038% Params, 3.76 MMac, 0.043% MACs, 384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (2): LayerNorm(768, 0.002% Params, 75.26 KMac, 0.001% MACs, (384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(591.36 k, 1.177% Params, 115.61 MMac, 1.326% MACs, in_features=384, out_features=1536, bias=True)
#           (4): GELU(0, 0.000% Params, 301.06 KMac, 0.003% MACs, approximate='none')
#           (5): Linear(590.21 k, 1.175% Params, 115.61 MMac, 1.326% MACs, in_features=1536, out_features=384, bias=True)
#           (6): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (stochastic_depth): StochasticDepth(p=0.3657142857142857, mode=row)
#       )
#     )
#     (6): Sequential(
#       1.18 M, 2.350% Params, 57.84 MMac, 0.663% MACs,
#       (0): LayerNorm2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (384,), eps=1e-06, elementwise_affine=True)
#       (1): Conv2d(1.18 M, 2.350% Params, 57.84 MMac, 0.663% MACs, 384, 768, kernel_size=(2, 2), stride=(2, 2))
#     )
#     (7): Sequential(
#       14.29 M, 28.447% Params, 699.85 MMac, 8.026% MACs,
#       (0): CNBlock(
#         4.76 M, 9.482% Params, 233.28 MMac, 2.675% MACs,
#         (block): Sequential(
#           4.76 M, 9.482% Params, 233.28 MMac, 2.675% MACs,
#           (0): Conv2d(38.4 k, 0.076% Params, 1.88 MMac, 0.022% MACs, 768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (2): LayerNorm(1.54 k, 0.003% Params, 37.63 KMac, 0.000% MACs, (768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(2.36 M, 4.704% Params, 115.61 MMac, 1.326% MACs, in_features=768, out_features=3072, bias=True)
#           (4): GELU(0, 0.000% Params, 150.53 KMac, 0.002% MACs, approximate='none')
#           (5): Linear(2.36 M, 4.699% Params, 115.61 MMac, 1.326% MACs, in_features=3072, out_features=768, bias=True)
#           (6): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (stochastic_depth): StochasticDepth(p=0.37714285714285717, mode=row)
#       )
#       (1): CNBlock(
#         4.76 M, 9.482% Params, 233.28 MMac, 2.675% MACs,
#         (block): Sequential(
#           4.76 M, 9.482% Params, 233.28 MMac, 2.675% MACs,
#           (0): Conv2d(38.4 k, 0.076% Params, 1.88 MMac, 0.022% MACs, 768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (2): LayerNorm(1.54 k, 0.003% Params, 37.63 KMac, 0.000% MACs, (768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(2.36 M, 4.704% Params, 115.61 MMac, 1.326% MACs, in_features=768, out_features=3072, bias=True)
#           (4): GELU(0, 0.000% Params, 150.53 KMac, 0.002% MACs, approximate='none')
#           (5): Linear(2.36 M, 4.699% Params, 115.61 MMac, 1.326% MACs, in_features=3072, out_features=768, bias=True)
#           (6): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (stochastic_depth): StochasticDepth(p=0.3885714285714286, mode=row)
#       )
#       (2): CNBlock(
#         4.76 M, 9.482% Params, 233.28 MMac, 2.675% MACs,
#         (block): Sequential(
#           4.76 M, 9.482% Params, 233.28 MMac, 2.675% MACs,
#           (0): Conv2d(38.4 k, 0.076% Params, 1.88 MMac, 0.022% MACs, 768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           (2): LayerNorm(1.54 k, 0.003% Params, 37.63 KMac, 0.000% MACs, (768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(2.36 M, 4.704% Params, 115.61 MMac, 1.326% MACs, in_features=768, out_features=3072, bias=True)
#           (4): GELU(0, 0.000% Params, 150.53 KMac, 0.002% MACs, approximate='none')
#           (5): Linear(2.36 M, 4.699% Params, 115.61 MMac, 1.326% MACs, in_features=3072, out_features=768, bias=True)
#           (6): Permute(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#         )
#         (stochastic_depth): StochasticDepth(p=0.4, mode=row)
#       )
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 37.63 KMac, 0.000% MACs, output_size=1)
#   (classifier): Sequential(
#     769.0 k, 1.531% Params, 769.0 KMac, 0.009% MACs,
#     (0): LayerNorm2d(0, 0.000% Params, 0.0 Mac, 0.000% MACs, (768,), eps=1e-06, elementwise_affine=True)
#     (1): Flatten(0, 0.000% Params, 0.0 Mac, 0.000% MACs, start_dim=1, end_dim=-1)
#     (2): Linear(769.0 k, 1.531% Params, 769.0 KMac, 0.009% MACs, in_features=768, out_features=1000, bias=True)
#   )
# )
# Computational complexity:       8.72 GMac
# Number of parameters:           50.22 M

# %%
with torch.cuda.device(0):
  net = models.efficientnet_v2_m(weights=None)

  macs, params = get_model_complexity_info(net, (3, 224, 224), as_strings=True,
                                           print_per_layer_stat=True, verbose=True)
  print('{:<30}  {:<8}'.format('Computational complexity: ', macs))
  print('{:<30}  {:<8}'.format('Number of parameters: ', params))
# Out:
# Warning: module SiLU is treated as a zero-op.
# Warning: module Conv2dNormActivation is treated as a zero-op.
# Warning: module StochasticDepth is treated as a zero-op.
# Warning: module FusedMBConv is treated as a zero-op.
# Warning: module Sigmoid is treated as a zero-op.
# Warning: module SqueezeExcitation is treated as a zero-op.
# Warning: module MBConv is treated as a zero-op.
# Warning: module Dropout is treated as a zero-op.
# Warning: module EfficientNet is treated as a zero-op.
# EfficientNet(
#   54.14 M, 100.000% Params, 5.41 GMac, 99.569% MACs,
#   (features): Sequential(
#     52.86 M, 97.634% Params, 5.41 GMac, 99.544% MACs,
#     (0): Conv2dNormActivation(
#       696, 0.001% Params, 8.73 MMac, 0.161% MACs,
#       (0): Conv2d(648, 0.001% Params, 8.13 MMac, 0.150% MACs, 3, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(48, 0.000% Params, 602.11 KMac, 0.011% MACs, 24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#     )
#     (1): Sequential(
#       15.7 k, 0.029% Params, 196.89 MMac, 3.625% MACs,
#       (0): FusedMBConv(
#         5.23 k, 0.010% Params, 65.63 MMac, 1.208% MACs,
#         (block): Sequential(
#           5.23 k, 0.010% Params, 65.63 MMac, 1.208% MACs,
#           (0): Conv2dNormActivation(
#             5.23 k, 0.010% Params, 65.63 MMac, 1.208% MACs,
#             (0): Conv2d(5.18 k, 0.010% Params, 65.03 MMac, 1.197% MACs, 24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(48, 0.000% Params, 602.11 KMac, 0.011% MACs, 24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#       )
#       (1): FusedMBConv(
#         5.23 k, 0.010% Params, 65.63 MMac, 1.208% MACs,
#         (block): Sequential(
#           5.23 k, 0.010% Params, 65.63 MMac, 1.208% MACs,
#           (0): Conv2dNormActivation(
#             5.23 k, 0.010% Params, 65.63 MMac, 1.208% MACs,
#             (0): Conv2d(5.18 k, 0.010% Params, 65.03 MMac, 1.197% MACs, 24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(48, 0.000% Params, 602.11 KMac, 0.011% MACs, 24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0035087719298245615, mode=row)
#       )
#       (2): FusedMBConv(
#         5.23 k, 0.010% Params, 65.63 MMac, 1.208% MACs,
#         (block): Sequential(
#           5.23 k, 0.010% Params, 65.63 MMac, 1.208% MACs,
#           (0): Conv2dNormActivation(
#             5.23 k, 0.010% Params, 65.63 MMac, 1.208% MACs,
#             (0): Conv2d(5.18 k, 0.010% Params, 65.03 MMac, 1.197% MACs, 24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(48, 0.000% Params, 602.11 KMac, 0.011% MACs, 24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.007017543859649123, mode=row)
#       )
#     )
#     (2): Sequential(
#       396.19 k, 0.732% Params, 1.24 GMac, 22.878% MACs,
#       (0): FusedMBConv(
#         25.63 k, 0.047% Params, 80.38 MMac, 1.480% MACs,
#         (block): Sequential(
#           25.63 k, 0.047% Params, 80.38 MMac, 1.480% MACs,
#           (0): Conv2dNormActivation(
#             20.93 k, 0.039% Params, 65.63 MMac, 1.208% MACs,
#             (0): Conv2d(20.74 k, 0.038% Params, 65.03 MMac, 1.197% MACs, 24, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(192, 0.000% Params, 602.11 KMac, 0.011% MACs, 96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             4.7 k, 0.009% Params, 14.75 MMac, 0.272% MACs,
#             (0): Conv2d(4.61 k, 0.009% Params, 14.45 MMac, 0.266% MACs, 96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, 0.000% Params, 301.06 KMac, 0.006% MACs, 48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.010526315789473686, mode=row)
#       )
#       (1): FusedMBConv(
#         92.64 k, 0.171% Params, 290.52 MMac, 5.349% MACs,
#         (block): Sequential(
#           92.64 k, 0.171% Params, 290.52 MMac, 5.349% MACs,
#           (0): Conv2dNormActivation(
#             83.33 k, 0.154% Params, 261.32 MMac, 4.812% MACs,
#             (0): Conv2d(82.94 k, 0.153% Params, 260.11 MMac, 4.790% MACs, 48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(384, 0.001% Params, 1.2 MMac, 0.022% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             9.31 k, 0.017% Params, 29.2 MMac, 0.538% MACs,
#             (0): Conv2d(9.22 k, 0.017% Params, 28.9 MMac, 0.532% MACs, 192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, 0.000% Params, 301.06 KMac, 0.006% MACs, 48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.014035087719298246, mode=row)
#       )
#       (2): FusedMBConv(
#         92.64 k, 0.171% Params, 290.52 MMac, 5.349% MACs,
#         (block): Sequential(
#           92.64 k, 0.171% Params, 290.52 MMac, 5.349% MACs,
#           (0): Conv2dNormActivation(
#             83.33 k, 0.154% Params, 261.32 MMac, 4.812% MACs,
#             (0): Conv2d(82.94 k, 0.153% Params, 260.11 MMac, 4.790% MACs, 48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(384, 0.001% Params, 1.2 MMac, 0.022% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             9.31 k, 0.017% Params, 29.2 MMac, 0.538% MACs,
#             (0): Conv2d(9.22 k, 0.017% Params, 28.9 MMac, 0.532% MACs, 192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, 0.000% Params, 301.06 KMac, 0.006% MACs, 48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.017543859649122806, mode=row)
#       )
#       (3): FusedMBConv(
#         92.64 k, 0.171% Params, 290.52 MMac, 5.349% MACs,
#         (block): Sequential(
#           92.64 k, 0.171% Params, 290.52 MMac, 5.349% MACs,
#           (0): Conv2dNormActivation(
#             83.33 k, 0.154% Params, 261.32 MMac, 4.812% MACs,
#             (0): Conv2d(82.94 k, 0.153% Params, 260.11 MMac, 4.790% MACs, 48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(384, 0.001% Params, 1.2 MMac, 0.022% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             9.31 k, 0.017% Params, 29.2 MMac, 0.538% MACs,
#             (0): Conv2d(9.22 k, 0.017% Params, 28.9 MMac, 0.532% MACs, 192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, 0.000% Params, 301.06 KMac, 0.006% MACs, 48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.02105263157894737, mode=row)
#       )
#       (4): FusedMBConv(
#         92.64 k, 0.171% Params, 290.52 MMac, 5.349% MACs,
#         (block): Sequential(
#           92.64 k, 0.171% Params, 290.52 MMac, 5.349% MACs,
#           (0): Conv2dNormActivation(
#             83.33 k, 0.154% Params, 261.32 MMac, 4.812% MACs,
#             (0): Conv2d(82.94 k, 0.153% Params, 260.11 MMac, 4.790% MACs, 48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(384, 0.001% Params, 1.2 MMac, 0.022% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             9.31 k, 0.017% Params, 29.2 MMac, 0.538% MACs,
#             (0): Conv2d(9.22 k, 0.017% Params, 28.9 MMac, 0.532% MACs, 192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, 0.000% Params, 301.06 KMac, 0.006% MACs, 48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.024561403508771933, mode=row)
#       )
#     )
#     (3): Sequential(
#       1.13 M, 2.080% Params, 882.82 MMac, 16.256% MACs,
#       (0): FusedMBConv(
#         98.85 k, 0.183% Params, 77.5 MMac, 1.427% MACs,
#         (block): Sequential(
#           98.85 k, 0.183% Params, 77.5 MMac, 1.427% MACs,
#           (0): Conv2dNormActivation(
#             83.33 k, 0.154% Params, 65.33 MMac, 1.203% MACs,
#             (0): Conv2d(82.94 k, 0.153% Params, 65.03 MMac, 1.197% MACs, 48, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(384, 0.001% Params, 301.06 KMac, 0.006% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             15.52 k, 0.029% Params, 12.17 MMac, 0.224% MACs,
#             (0): Conv2d(15.36 k, 0.028% Params, 12.04 MMac, 0.222% MACs, 192, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, 0.000% Params, 125.44 KMac, 0.002% MACs, 80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.028070175438596492, mode=row)
#       )
#       (1): FusedMBConv(
#         256.8 k, 0.474% Params, 201.33 MMac, 3.707% MACs,
#         (block): Sequential(
#           256.8 k, 0.474% Params, 201.33 MMac, 3.707% MACs,
#           (0): Conv2dNormActivation(
#             231.04 k, 0.427% Params, 181.14 MMac, 3.335% MACs,
#             (0): Conv2d(230.4 k, 0.426% Params, 180.63 MMac, 3.326% MACs, 80, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(640, 0.001% Params, 501.76 KMac, 0.009% MACs, 320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             25.76 k, 0.048% Params, 20.2 MMac, 0.372% MACs,
#             (0): Conv2d(25.6 k, 0.047% Params, 20.07 MMac, 0.370% MACs, 320, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, 0.000% Params, 125.44 KMac, 0.002% MACs, 80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.031578947368421054, mode=row)
#       )
#       (2): FusedMBConv(
#         256.8 k, 0.474% Params, 201.33 MMac, 3.707% MACs,
#         (block): Sequential(
#           256.8 k, 0.474% Params, 201.33 MMac, 3.707% MACs,
#           (0): Conv2dNormActivation(
#             231.04 k, 0.427% Params, 181.14 MMac, 3.335% MACs,
#             (0): Conv2d(230.4 k, 0.426% Params, 180.63 MMac, 3.326% MACs, 80, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(640, 0.001% Params, 501.76 KMac, 0.009% MACs, 320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             25.76 k, 0.048% Params, 20.2 MMac, 0.372% MACs,
#             (0): Conv2d(25.6 k, 0.047% Params, 20.07 MMac, 0.370% MACs, 320, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, 0.000% Params, 125.44 KMac, 0.002% MACs, 80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.03508771929824561, mode=row)
#       )
#       (3): FusedMBConv(
#         256.8 k, 0.474% Params, 201.33 MMac, 3.707% MACs,
#         (block): Sequential(
#           256.8 k, 0.474% Params, 201.33 MMac, 3.707% MACs,
#           (0): Conv2dNormActivation(
#             231.04 k, 0.427% Params, 181.14 MMac, 3.335% MACs,
#             (0): Conv2d(230.4 k, 0.426% Params, 180.63 MMac, 3.326% MACs, 80, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(640, 0.001% Params, 501.76 KMac, 0.009% MACs, 320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             25.76 k, 0.048% Params, 20.2 MMac, 0.372% MACs,
#             (0): Conv2d(25.6 k, 0.047% Params, 20.07 MMac, 0.370% MACs, 320, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, 0.000% Params, 125.44 KMac, 0.002% MACs, 80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.03859649122807018, mode=row)
#       )
#       (4): FusedMBConv(
#         256.8 k, 0.474% Params, 201.33 MMac, 3.707% MACs,
#         (block): Sequential(
#           256.8 k, 0.474% Params, 201.33 MMac, 3.707% MACs,
#           (0): Conv2dNormActivation(
#             231.04 k, 0.427% Params, 181.14 MMac, 3.335% MACs,
#             (0): Conv2d(230.4 k, 0.426% Params, 180.63 MMac, 3.326% MACs, 80, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(640, 0.001% Params, 501.76 KMac, 0.009% MACs, 320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             25.76 k, 0.048% Params, 20.2 MMac, 0.372% MACs,
#             (0): Conv2d(25.6 k, 0.047% Params, 20.07 MMac, 0.370% MACs, 320, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, 0.000% Params, 125.44 KMac, 0.002% MACs, 80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.04210526315789474, mode=row)
#       )
#     )
#     (4): Sequential(
#       1.69 M, 3.115% Params, 283.51 MMac, 5.220% MACs,
#       (0): MBConv(
#         94.42 k, 0.174% Params, 31.44 MMac, 0.579% MACs,
#         (block): Sequential(
#           94.42 k, 0.174% Params, 31.44 MMac, 0.579% MACs,
#           (0): Conv2dNormActivation(
#             26.24 k, 0.048% Params, 20.57 MMac, 0.379% MACs,
#             (0): Conv2d(25.6 k, 0.047% Params, 20.07 MMac, 0.370% MACs, 80, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(640, 0.001% Params, 501.76 KMac, 0.009% MACs, 320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             3.52 k, 0.007% Params, 689.92 KMac, 0.013% MACs,
#             (0): Conv2d(2.88 k, 0.005% Params, 564.48 KMac, 0.010% MACs, 320, 320, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=320, bias=False)
#             (1): BatchNorm2d(640, 0.001% Params, 125.44 KMac, 0.002% MACs, 320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             13.14 k, 0.024% Params, 75.86 KMac, 0.001% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 62.72 KMac, 0.001% MACs, output_size=1)
#             (fc1): Conv2d(6.42 k, 0.012% Params, 6.42 KMac, 0.000% MACs, 320, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6.72 k, 0.012% Params, 6.72 KMac, 0.000% MACs, 20, 320, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             51.52 k, 0.095% Params, 10.1 MMac, 0.186% MACs,
#             (0): Conv2d(51.2 k, 0.095% Params, 10.04 MMac, 0.185% MACs, 320, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(320, 0.001% Params, 62.72 KMac, 0.001% MACs, 160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0456140350877193, mode=row)
#       )
#       (1): MBConv(
#         265.32 k, 0.490% Params, 42.01 MMac, 0.774% MACs,
#         (block): Sequential(
#           265.32 k, 0.490% Params, 42.01 MMac, 0.774% MACs,
#           (0): Conv2dNormActivation(
#             103.68 k, 0.192% Params, 20.32 MMac, 0.374% MACs,
#             (0): Conv2d(102.4 k, 0.189% Params, 20.07 MMac, 0.370% MACs, 160, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1.28 k, 0.002% Params, 250.88 KMac, 0.005% MACs, 640, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             7.04 k, 0.013% Params, 1.38 MMac, 0.025% MACs,
#             (0): Conv2d(5.76 k, 0.011% Params, 1.13 MMac, 0.021% MACs, 640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=640, bias=False)
#             (1): BatchNorm2d(1.28 k, 0.002% Params, 250.88 KMac, 0.005% MACs, 640, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             51.88 k, 0.096% Params, 177.32 KMac, 0.003% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 125.44 KMac, 0.002% MACs, output_size=1)
#             (fc1): Conv2d(25.64 k, 0.047% Params, 25.64 KMac, 0.000% MACs, 640, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(26.24 k, 0.048% Params, 26.24 KMac, 0.000% MACs, 40, 640, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             102.72 k, 0.190% Params, 20.13 MMac, 0.371% MACs,
#             (0): Conv2d(102.4 k, 0.189% Params, 20.07 MMac, 0.370% MACs, 640, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(320, 0.001% Params, 62.72 KMac, 0.001% MACs, 160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.04912280701754387, mode=row)
#       )
#       (2): MBConv(
#         265.32 k, 0.490% Params, 42.01 MMac, 0.774% MACs,
#         (block): Sequential(
#           265.32 k, 0.490% Params, 42.01 MMac, 0.774% MACs,
#           (0): Conv2dNormActivation(
#             103.68 k, 0.192% Params, 20.32 MMac, 0.374% MACs,
#             (0): Conv2d(102.4 k, 0.189% Params, 20.07 MMac, 0.370% MACs, 160, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1.28 k, 0.002% Params, 250.88 KMac, 0.005% MACs, 640, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             7.04 k, 0.013% Params, 1.38 MMac, 0.025% MACs,
#             (0): Conv2d(5.76 k, 0.011% Params, 1.13 MMac, 0.021% MACs, 640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=640, bias=False)
#             (1): BatchNorm2d(1.28 k, 0.002% Params, 250.88 KMac, 0.005% MACs, 640, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             51.88 k, 0.096% Params, 177.32 KMac, 0.003% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 125.44 KMac, 0.002% MACs, output_size=1)
#             (fc1): Conv2d(25.64 k, 0.047% Params, 25.64 KMac, 0.000% MACs, 640, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(26.24 k, 0.048% Params, 26.24 KMac, 0.000% MACs, 40, 640, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             102.72 k, 0.190% Params, 20.13 MMac, 0.371% MACs,
#             (0): Conv2d(102.4 k, 0.189% Params, 20.07 MMac, 0.370% MACs, 640, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(320, 0.001% Params, 62.72 KMac, 0.001% MACs, 160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05263157894736842, mode=row)
#       )
#       (3): MBConv(
#         265.32 k, 0.490% Params, 42.01 MMac, 0.774% MACs,
#         (block): Sequential(
#           265.32 k, 0.490% Params, 42.01 MMac, 0.774% MACs,
#           (0): Conv2dNormActivation(
#             103.68 k, 0.192% Params, 20.32 MMac, 0.374% MACs,
#             (0): Conv2d(102.4 k, 0.189% Params, 20.07 MMac, 0.370% MACs, 160, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1.28 k, 0.002% Params, 250.88 KMac, 0.005% MACs, 640, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             7.04 k, 0.013% Params, 1.38 MMac, 0.025% MACs,
#             (0): Conv2d(5.76 k, 0.011% Params, 1.13 MMac, 0.021% MACs, 640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=640, bias=False)
#             (1): BatchNorm2d(1.28 k, 0.002% Params, 250.88 KMac, 0.005% MACs, 640, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             51.88 k, 0.096% Params, 177.32 KMac, 0.003% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 125.44 KMac, 0.002% MACs, output_size=1)
#             (fc1): Conv2d(25.64 k, 0.047% Params, 25.64 KMac, 0.000% MACs, 640, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(26.24 k, 0.048% Params, 26.24 KMac, 0.000% MACs, 40, 640, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             102.72 k, 0.190% Params, 20.13 MMac, 0.371% MACs,
#             (0): Conv2d(102.4 k, 0.189% Params, 20.07 MMac, 0.370% MACs, 640, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(320, 0.001% Params, 62.72 KMac, 0.001% MACs, 160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.056140350877192984, mode=row)
#       )
#       (4): MBConv(
#         265.32 k, 0.490% Params, 42.01 MMac, 0.774% MACs,
#         (block): Sequential(
#           265.32 k, 0.490% Params, 42.01 MMac, 0.774% MACs,
#           (0): Conv2dNormActivation(
#             103.68 k, 0.192% Params, 20.32 MMac, 0.374% MACs,
#             (0): Conv2d(102.4 k, 0.189% Params, 20.07 MMac, 0.370% MACs, 160, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1.28 k, 0.002% Params, 250.88 KMac, 0.005% MACs, 640, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             7.04 k, 0.013% Params, 1.38 MMac, 0.025% MACs,
#             (0): Conv2d(5.76 k, 0.011% Params, 1.13 MMac, 0.021% MACs, 640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=640, bias=False)
#             (1): BatchNorm2d(1.28 k, 0.002% Params, 250.88 KMac, 0.005% MACs, 640, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             51.88 k, 0.096% Params, 177.32 KMac, 0.003% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 125.44 KMac, 0.002% MACs, output_size=1)
#             (fc1): Conv2d(25.64 k, 0.047% Params, 25.64 KMac, 0.000% MACs, 640, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(26.24 k, 0.048% Params, 26.24 KMac, 0.000% MACs, 40, 640, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             102.72 k, 0.190% Params, 20.13 MMac, 0.371% MACs,
#             (0): Conv2d(102.4 k, 0.189% Params, 20.07 MMac, 0.370% MACs, 640, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(320, 0.001% Params, 62.72 KMac, 0.001% MACs, 160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05964912280701755, mode=row)
#       )
#       (5): MBConv(
#         265.32 k, 0.490% Params, 42.01 MMac, 0.774% MACs,
#         (block): Sequential(
#           265.32 k, 0.490% Params, 42.01 MMac, 0.774% MACs,
#           (0): Conv2dNormActivation(
#             103.68 k, 0.192% Params, 20.32 MMac, 0.374% MACs,
#             (0): Conv2d(102.4 k, 0.189% Params, 20.07 MMac, 0.370% MACs, 160, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1.28 k, 0.002% Params, 250.88 KMac, 0.005% MACs, 640, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             7.04 k, 0.013% Params, 1.38 MMac, 0.025% MACs,
#             (0): Conv2d(5.76 k, 0.011% Params, 1.13 MMac, 0.021% MACs, 640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=640, bias=False)
#             (1): BatchNorm2d(1.28 k, 0.002% Params, 250.88 KMac, 0.005% MACs, 640, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             51.88 k, 0.096% Params, 177.32 KMac, 0.003% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 125.44 KMac, 0.002% MACs, output_size=1)
#             (fc1): Conv2d(25.64 k, 0.047% Params, 25.64 KMac, 0.000% MACs, 640, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(26.24 k, 0.048% Params, 26.24 KMac, 0.000% MACs, 40, 640, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             102.72 k, 0.190% Params, 20.13 MMac, 0.371% MACs,
#             (0): Conv2d(102.4 k, 0.189% Params, 20.07 MMac, 0.370% MACs, 640, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(320, 0.001% Params, 62.72 KMac, 0.001% MACs, 160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.06315789473684211, mode=row)
#       )
#       (6): MBConv(
#         265.32 k, 0.490% Params, 42.01 MMac, 0.774% MACs,
#         (block): Sequential(
#           265.32 k, 0.490% Params, 42.01 MMac, 0.774% MACs,
#           (0): Conv2dNormActivation(
#             103.68 k, 0.192% Params, 20.32 MMac, 0.374% MACs,
#             (0): Conv2d(102.4 k, 0.189% Params, 20.07 MMac, 0.370% MACs, 160, 640, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1.28 k, 0.002% Params, 250.88 KMac, 0.005% MACs, 640, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             7.04 k, 0.013% Params, 1.38 MMac, 0.025% MACs,
#             (0): Conv2d(5.76 k, 0.011% Params, 1.13 MMac, 0.021% MACs, 640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=640, bias=False)
#             (1): BatchNorm2d(1.28 k, 0.002% Params, 250.88 KMac, 0.005% MACs, 640, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             51.88 k, 0.096% Params, 177.32 KMac, 0.003% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 125.44 KMac, 0.002% MACs, output_size=1)
#             (fc1): Conv2d(25.64 k, 0.047% Params, 25.64 KMac, 0.000% MACs, 640, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(26.24 k, 0.048% Params, 26.24 KMac, 0.000% MACs, 40, 640, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             102.72 k, 0.190% Params, 20.13 MMac, 0.371% MACs,
#             (0): Conv2d(102.4 k, 0.189% Params, 20.07 MMac, 0.370% MACs, 640, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(320, 0.001% Params, 62.72 KMac, 0.001% MACs, 160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.06666666666666667, mode=row)
#       )
#     )
#     (5): Sequential(
#       6.65 M, 12.285% Params, 1.05 GMac, 19.388% MACs,
#       (0): MBConv(
#         413.19 k, 0.763% Params, 66.0 MMac, 1.215% MACs,
#         (block): Sequential(
#           413.19 k, 0.763% Params, 66.0 MMac, 1.215% MACs,
#           (0): Conv2dNormActivation(
#             155.52 k, 0.287% Params, 30.48 MMac, 0.561% MACs,
#             (0): Conv2d(153.6 k, 0.284% Params, 30.11 MMac, 0.554% MACs, 160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1.92 k, 0.004% Params, 376.32 KMac, 0.007% MACs, 960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             10.56 k, 0.020% Params, 2.07 MMac, 0.038% MACs,
#             (0): Conv2d(8.64 k, 0.016% Params, 1.69 MMac, 0.031% MACs, 960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(1.92 k, 0.004% Params, 376.32 KMac, 0.007% MACs, 960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             77.8 k, 0.144% Params, 265.96 KMac, 0.005% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 188.16 KMac, 0.003% MACs, output_size=1)
#             (fc1): Conv2d(38.44 k, 0.071% Params, 38.44 KMac, 0.001% MACs, 960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(39.36 k, 0.073% Params, 39.36 KMac, 0.001% MACs, 40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             169.31 k, 0.313% Params, 33.19 MMac, 0.611% MACs,
#             (0): Conv2d(168.96 k, 0.312% Params, 33.12 MMac, 0.610% MACs, 960, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(352, 0.001% Params, 68.99 KMac, 0.001% MACs, 176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.07017543859649122, mode=row)
#       )
#       (1): MBConv(
#         479.82 k, 0.886% Params, 75.92 MMac, 1.398% MACs,
#         (block): Sequential(
#           479.82 k, 0.886% Params, 75.92 MMac, 1.398% MACs,
#           (0): Conv2dNormActivation(
#             187.97 k, 0.347% Params, 36.84 MMac, 0.678% MACs,
#             (0): Conv2d(185.86 k, 0.343% Params, 36.43 MMac, 0.671% MACs, 176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2.11 k, 0.004% Params, 413.95 KMac, 0.008% MACs, 1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             11.62 k, 0.021% Params, 2.28 MMac, 0.042% MACs,
#             (0): Conv2d(9.5 k, 0.018% Params, 1.86 MMac, 0.034% MACs, 1056, 1056, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1056, bias=False)
#             (1): BatchNorm2d(2.11 k, 0.004% Params, 413.95 KMac, 0.008% MACs, 1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             94.03 k, 0.174% Params, 301.0 KMac, 0.006% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 206.98 KMac, 0.004% MACs, output_size=1)
#             (fc1): Conv2d(46.51 k, 0.086% Params, 46.51 KMac, 0.001% MACs, 1056, 44, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(47.52 k, 0.088% Params, 47.52 KMac, 0.001% MACs, 44, 1056, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             186.21 k, 0.344% Params, 36.5 MMac, 0.672% MACs,
#             (0): Conv2d(185.86 k, 0.343% Params, 36.43 MMac, 0.671% MACs, 1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(352, 0.001% Params, 68.99 KMac, 0.001% MACs, 176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0736842105263158, mode=row)
#       )
#       (2): MBConv(
#         479.82 k, 0.886% Params, 75.92 MMac, 1.398% MACs,
#         (block): Sequential(
#           479.82 k, 0.886% Params, 75.92 MMac, 1.398% MACs,
#           (0): Conv2dNormActivation(
#             187.97 k, 0.347% Params, 36.84 MMac, 0.678% MACs,
#             (0): Conv2d(185.86 k, 0.343% Params, 36.43 MMac, 0.671% MACs, 176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2.11 k, 0.004% Params, 413.95 KMac, 0.008% MACs, 1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             11.62 k, 0.021% Params, 2.28 MMac, 0.042% MACs,
#             (0): Conv2d(9.5 k, 0.018% Params, 1.86 MMac, 0.034% MACs, 1056, 1056, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1056, bias=False)
#             (1): BatchNorm2d(2.11 k, 0.004% Params, 413.95 KMac, 0.008% MACs, 1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             94.03 k, 0.174% Params, 301.0 KMac, 0.006% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 206.98 KMac, 0.004% MACs, output_size=1)
#             (fc1): Conv2d(46.51 k, 0.086% Params, 46.51 KMac, 0.001% MACs, 1056, 44, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(47.52 k, 0.088% Params, 47.52 KMac, 0.001% MACs, 44, 1056, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             186.21 k, 0.344% Params, 36.5 MMac, 0.672% MACs,
#             (0): Conv2d(185.86 k, 0.343% Params, 36.43 MMac, 0.671% MACs, 1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(352, 0.001% Params, 68.99 KMac, 0.001% MACs, 176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.07719298245614035, mode=row)
#       )
#       (3): MBConv(
#         479.82 k, 0.886% Params, 75.92 MMac, 1.398% MACs,
#         (block): Sequential(
#           479.82 k, 0.886% Params, 75.92 MMac, 1.398% MACs,
#           (0): Conv2dNormActivation(
#             187.97 k, 0.347% Params, 36.84 MMac, 0.678% MACs,
#             (0): Conv2d(185.86 k, 0.343% Params, 36.43 MMac, 0.671% MACs, 176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2.11 k, 0.004% Params, 413.95 KMac, 0.008% MACs, 1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             11.62 k, 0.021% Params, 2.28 MMac, 0.042% MACs,
#             (0): Conv2d(9.5 k, 0.018% Params, 1.86 MMac, 0.034% MACs, 1056, 1056, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1056, bias=False)
#             (1): BatchNorm2d(2.11 k, 0.004% Params, 413.95 KMac, 0.008% MACs, 1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             94.03 k, 0.174% Params, 301.0 KMac, 0.006% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 206.98 KMac, 0.004% MACs, output_size=1)
#             (fc1): Conv2d(46.51 k, 0.086% Params, 46.51 KMac, 0.001% MACs, 1056, 44, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(47.52 k, 0.088% Params, 47.52 KMac, 0.001% MACs, 44, 1056, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             186.21 k, 0.344% Params, 36.5 MMac, 0.672% MACs,
#             (0): Conv2d(185.86 k, 0.343% Params, 36.43 MMac, 0.671% MACs, 1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(352, 0.001% Params, 68.99 KMac, 0.001% MACs, 176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08070175438596493, mode=row)
#       )
#       (4): MBConv(
#         479.82 k, 0.886% Params, 75.92 MMac, 1.398% MACs,
#         (block): Sequential(
#           479.82 k, 0.886% Params, 75.92 MMac, 1.398% MACs,
#           (0): Conv2dNormActivation(
#             187.97 k, 0.347% Params, 36.84 MMac, 0.678% MACs,
#             (0): Conv2d(185.86 k, 0.343% Params, 36.43 MMac, 0.671% MACs, 176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2.11 k, 0.004% Params, 413.95 KMac, 0.008% MACs, 1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             11.62 k, 0.021% Params, 2.28 MMac, 0.042% MACs,
#             (0): Conv2d(9.5 k, 0.018% Params, 1.86 MMac, 0.034% MACs, 1056, 1056, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1056, bias=False)
#             (1): BatchNorm2d(2.11 k, 0.004% Params, 413.95 KMac, 0.008% MACs, 1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             94.03 k, 0.174% Params, 301.0 KMac, 0.006% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 206.98 KMac, 0.004% MACs, output_size=1)
#             (fc1): Conv2d(46.51 k, 0.086% Params, 46.51 KMac, 0.001% MACs, 1056, 44, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(47.52 k, 0.088% Params, 47.52 KMac, 0.001% MACs, 44, 1056, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             186.21 k, 0.344% Params, 36.5 MMac, 0.672% MACs,
#             (0): Conv2d(185.86 k, 0.343% Params, 36.43 MMac, 0.671% MACs, 1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(352, 0.001% Params, 68.99 KMac, 0.001% MACs, 176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08421052631578949, mode=row)
#       )
#       (5): MBConv(
#         479.82 k, 0.886% Params, 75.92 MMac, 1.398% MACs,
#         (block): Sequential(
#           479.82 k, 0.886% Params, 75.92 MMac, 1.398% MACs,
#           (0): Conv2dNormActivation(
#             187.97 k, 0.347% Params, 36.84 MMac, 0.678% MACs,
#             (0): Conv2d(185.86 k, 0.343% Params, 36.43 MMac, 0.671% MACs, 176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2.11 k, 0.004% Params, 413.95 KMac, 0.008% MACs, 1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             11.62 k, 0.021% Params, 2.28 MMac, 0.042% MACs,
#             (0): Conv2d(9.5 k, 0.018% Params, 1.86 MMac, 0.034% MACs, 1056, 1056, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1056, bias=False)
#             (1): BatchNorm2d(2.11 k, 0.004% Params, 413.95 KMac, 0.008% MACs, 1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             94.03 k, 0.174% Params, 301.0 KMac, 0.006% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 206.98 KMac, 0.004% MACs, output_size=1)
#             (fc1): Conv2d(46.51 k, 0.086% Params, 46.51 KMac, 0.001% MACs, 1056, 44, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(47.52 k, 0.088% Params, 47.52 KMac, 0.001% MACs, 44, 1056, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             186.21 k, 0.344% Params, 36.5 MMac, 0.672% MACs,
#             (0): Conv2d(185.86 k, 0.343% Params, 36.43 MMac, 0.671% MACs, 1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(352, 0.001% Params, 68.99 KMac, 0.001% MACs, 176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08771929824561403, mode=row)
#       )
#       (6): MBConv(
#         479.82 k, 0.886% Params, 75.92 MMac, 1.398% MACs,
#         (block): Sequential(
#           479.82 k, 0.886% Params, 75.92 MMac, 1.398% MACs,
#           (0): Conv2dNormActivation(
#             187.97 k, 0.347% Params, 36.84 MMac, 0.678% MACs,
#             (0): Conv2d(185.86 k, 0.343% Params, 36.43 MMac, 0.671% MACs, 176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2.11 k, 0.004% Params, 413.95 KMac, 0.008% MACs, 1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             11.62 k, 0.021% Params, 2.28 MMac, 0.042% MACs,
#             (0): Conv2d(9.5 k, 0.018% Params, 1.86 MMac, 0.034% MACs, 1056, 1056, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1056, bias=False)
#             (1): BatchNorm2d(2.11 k, 0.004% Params, 413.95 KMac, 0.008% MACs, 1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             94.03 k, 0.174% Params, 301.0 KMac, 0.006% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 206.98 KMac, 0.004% MACs, output_size=1)
#             (fc1): Conv2d(46.51 k, 0.086% Params, 46.51 KMac, 0.001% MACs, 1056, 44, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(47.52 k, 0.088% Params, 47.52 KMac, 0.001% MACs, 44, 1056, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             186.21 k, 0.344% Params, 36.5 MMac, 0.672% MACs,
#             (0): Conv2d(185.86 k, 0.343% Params, 36.43 MMac, 0.671% MACs, 1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(352, 0.001% Params, 68.99 KMac, 0.001% MACs, 176, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0912280701754386, mode=row)
#       )
#       (7): MBConv(
#         479.82 k, 0.886% Params, 75.92 MMac, 1.398% MACs,
#         (block): Sequential(
#           479.82 k, 0.886% Params, 75.92 MMac, 1.398% MACs,
#           (0): Conv2dNormActivation(
#             187.97 k, 0.347% Params, 36.84 MMac, 0.678% MACs,
#             (0): Conv2d(185.86 k, 0.343% Params, 36.43 MMac, 0.671% MACs, 176, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2.11 k, 0.004% Params, 413.95 KMac, 0.008% MACs, 1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             11.62 k, 0.021% Params, 2.28 MMac, 0.042% MACs,
#             (0): Conv2d(9.5 k, 0.018% Params, 1.86 MMac, 0.034% MACs, 1056, 1056, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1056, bias=False)
#             (1): BatchNorm2d(2.11 k, 0.004% Params, 413.95 KMac, 0.008% MACs, 1056, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             94.03 k, 0.174% Params, 301.0 KMac, 0.006% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 206.98 KMac, 0.004% MACs, output_size=1)
#             (fc1): Conv2d(46.51 k, 0.086% Params, 46.51 KMac, 0.001% MACs, 1056, 44, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(47.52 k, 0.088% Params, 47.52 KMac, 0.001% MACs, 44, 1056, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             186.21 k, 0.344% Params, 36.5 MMac, 0.672% MACs,
#             (0): Conv2d(185.86 k, 0.343% Params, 36.43 MMac, 0.671% MACs, 1056, 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...
#           )
#           (1): Conv2dNormActivation(
#             20.06 k, 0.037% Params, 983.14 KMac, 0.018% MACs,
#             (0): Conv2d(16.42 k, 0.030% Params, 804.38 KMac, 0.015% MACs, 1824, 1824, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1824, bias=False)
#             (1): BatchNorm2d(3.65 k, 0.007% Params, 178.75 KMac, 0.003% MACs, 1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             279.15 k, 0.516% Params, 368.52 KMac, 0.007% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 89.38 KMac, 0.002% MACs, output_size=1)
#             (fc1): Conv2d(138.7 k, 0.256% Params, 138.7 KMac, 0.003% MACs, 1824, 76, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(140.45 k, 0.259% Params, 140.45 KMac, 0.003% MACs, 76, 1824, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             555.1 k, 1.025% Params, 27.2 MMac, 0.501% MACs,
#             (0): Conv2d(554.5 k, 1.024% Params, 27.17 MMac, 0.500% MACs, 1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(608, 0.001% Params, 29.79 KMac, 0.001% MACs, 304, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17543859649122806, mode=row)
#       )
#       (17): MBConv(
#         1.41 M, 2.609% Params, 55.9 MMac, 1.029% MACs,
#         (block): Sequential(
#           1.41 M, 2.609% Params, 55.9 MMac, 1.029% MACs,
#           (0): Conv2dNormActivation(
#             558.14 k, 1.031% Params, 27.35 MMac, 0.504% MACs,
#             (0): Conv2d(554.5 k, 1.024% Params, 27.17 MMac, 0.500% MACs, 304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(3.65 k, 0.007% Params, 178.75 KMac, 0.003% MACs, 1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             20.06 k, 0.037% Params, 983.14 KMac, 0.018% MACs,
#             (0): Conv2d(16.42 k, 0.030% Params, 804.38 KMac, 0.015% MACs, 1824, 1824, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1824, bias=False)
#             (1): BatchNorm2d(3.65 k, 0.007% Params, 178.75 KMac, 0.003% MACs, 1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             279.15 k, 0.516% Params, 368.52 KMac, 0.007% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 89.38 KMac, 0.002% MACs, output_size=1)
#             (fc1): Conv2d(138.7 k, 0.256% Params, 138.7 KMac, 0.003% MACs, 1824, 76, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(140.45 k, 0.259% Params, 140.45 KMac, 0.003% MACs, 76, 1824, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             555.1 k, 1.025% Params, 27.2 MMac, 0.501% MACs,
#             (0): Conv2d(554.5 k, 1.024% Params, 27.17 MMac, 0.500% MACs, 1824, 304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(608, 0.001% Params, 29.79 KMac, 0.001% MACs, 304, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17894736842105266, mode=row)
#       )
#     )
#     (7): Sequential(
#       17.7 M, 32.689% Params, 702.86 MMac, 12.942% MACs,
#       (0): MBConv(
#         1.79 M, 3.310% Params, 74.51 MMac, 1.372% MACs,
#         (block): Sequential(
#           1.79 M, 3.310% Params, 74.51 MMac, 1.372% MACs,
#           (0): Conv2dNormActivation(
#             558.14 k, 1.031% Params, 27.35 MMac, 0.504% MACs,
#             (0): Conv2d(554.5 k, 1.024% Params, 27.17 MMac, 0.500% MACs, 304, 1824, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(3.65 k, 0.007% Params, 178.75 KMac, 0.003% MACs, 1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             20.06 k, 0.037% Params, 983.14 KMac, 0.018% MACs,
#             (0): Conv2d(16.42 k, 0.030% Params, 804.38 KMac, 0.015% MACs, 1824, 1824, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1824, bias=False)
#             (1): BatchNorm2d(3.65 k, 0.007% Params, 178.75 KMac, 0.003% MACs, 1824, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             279.15 k, 0.516% Params, 368.52 KMac, 0.007% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 89.38 KMac, 0.002% MACs, output_size=1)
#             (fc1): Conv2d(138.7 k, 0.256% Params, 138.7 KMac, 0.003% MACs, 1824, 76, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(140.45 k, 0.259% Params, 140.45 KMac, 0.003% MACs, 76, 1824, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             934.91 k, 1.727% Params, 45.81 MMac, 0.844% MACs,
#             (0): Conv2d(933.89 k, 1.725% Params, 45.76 MMac, 0.843% MACs, 1824, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1.02 k, 0.002% Params, 50.18 KMac, 0.001% MACs, 512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1824561403508772, mode=row)
#       )
#       (1): MBConv(
#         3.98 M, 7.345% Params, 157.09 MMac, 2.893% MACs,
#         (block): Sequential(
#           3.98 M, 7.345% Params, 157.09 MMac, 2.893% MACs,
#           (0): Conv2dNormActivation(
#             1.58 M, 2.917% Params, 77.37 MMac, 1.425% MACs,
#             (0): Conv2d(1.57 M, 2.905% Params, 77.07 MMac, 1.419% MACs, 512, 3072, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(6.14 k, 0.011% Params, 301.06 KMac, 0.006% MACs, 3072, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             33.79 k, 0.062% Params, 1.66 MMac, 0.030% MACs,
#             (0): Conv2d(27.65 k, 0.051% Params, 1.35 MMac, 0.025% MACs, 3072, 3072, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=3072, bias=False)
#             (1): BatchNorm2d(6.14 k, 0.011% Params, 301.06 KMac, 0.006% MACs, 3072, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             789.63 k, 1.459% Params, 940.16 KMac, 0.017% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 150.53 KMac, 0.003% MACs, output_size=1)
#             (fc1): Conv2d(393.34 k, 0.727% Params, 393.34 KMac, 0.007% MACs, 3072, 128, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(396.29 k, 0.732% Params, 396.29 KMac, 0.007% MACs, 128, 3072, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             1.57 M, 2.907% Params, 77.12 MMac, 1.420% MACs,
#             (0): Conv2d(1.57 M, 2.905% Params, 77.07 MMac, 1.419% MACs, 3072, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1.02 k, 0.002% Params, 50.18 KMac, 0.001% MACs, 512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.18596491228070178, mode=row)
#       )
#       (2): MBConv(
#         3.98 M, 7.345% Params, 157.09 MMac, 2.893% MACs,
#         (block): Sequential(
#           3.98 M, 7.345% Params, 157.09 MMac, 2.893% MACs,
#           (0): Conv2dNormActivation(
#             1.58 M, 2.917% Params, 77.37 MMac, 1.425% MACs,
#             (0): Conv2d(1.57 M, 2.905% Params, 77.07 MMac, 1.419% MACs, 512, 3072, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(6.14 k, 0.011% Params, 301.06 KMac, 0.006% MACs, 3072, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             33.79 k, 0.062% Params, 1.66 MMac, 0.030% MACs,
#             (0): Conv2d(27.65 k, 0.051% Params, 1.35 MMac, 0.025% MACs, 3072, 3072, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=3072, bias=False)
#             (1): BatchNorm2d(6.14 k, 0.011% Params, 301.06 KMac, 0.006% MACs, 3072, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             789.63 k, 1.459% Params, 940.16 KMac, 0.017% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 150.53 KMac, 0.003% MACs, output_size=1)
#             (fc1): Conv2d(393.34 k, 0.727% Params, 393.34 KMac, 0.007% MACs, 3072, 128, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(396.29 k, 0.732% Params, 396.29 KMac, 0.007% MACs, 128, 3072, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             1.57 M, 2.907% Params, 77.12 MMac, 1.420% MACs,
#             (0): Conv2d(1.57 M, 2.905% Params, 77.07 MMac, 1.419% MACs, 3072, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1.02 k, 0.002% Params, 50.18 KMac, 0.001% MACs, 512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.18947368421052632, mode=row)
#       )
#       (3): MBConv(
#         3.98 M, 7.345% Params, 157.09 MMac, 2.893% MACs,
#         (block): Sequential(
#           3.98 M, 7.345% Params, 157.09 MMac, 2.893% MACs,
#           (0): Conv2dNormActivation(
#             1.58 M, 2.917% Params, 77.37 MMac, 1.425% MACs,
#             (0): Conv2d(1.57 M, 2.905% Params, 77.07 MMac, 1.419% MACs, 512, 3072, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(6.14 k, 0.011% Params, 301.06 KMac, 0.006% MACs, 3072, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             33.79 k, 0.062% Params, 1.66 MMac, 0.030% MACs,
#             (0): Conv2d(27.65 k, 0.051% Params, 1.35 MMac, 0.025% MACs, 3072, 3072, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=3072, bias=False)
#             (1): BatchNorm2d(6.14 k, 0.011% Params, 301.06 KMac, 0.006% MACs, 3072, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             789.63 k, 1.459% Params, 940.16 KMac, 0.017% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 150.53 KMac, 0.003% MACs, output_size=1)
#             (fc1): Conv2d(393.34 k, 0.727% Params, 393.34 KMac, 0.007% MACs, 3072, 128, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(396.29 k, 0.732% Params, 396.29 KMac, 0.007% MACs, 128, 3072, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             1.57 M, 2.907% Params, 77.12 MMac, 1.420% MACs,
#             (0): Conv2d(1.57 M, 2.905% Params, 77.07 MMac, 1.419% MACs, 3072, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1.02 k, 0.002% Params, 50.18 KMac, 0.001% MACs, 512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.19298245614035087, mode=row)
#       )
#       (4): MBConv(
#         3.98 M, 7.345% Params, 157.09 MMac, 2.893% MACs,
#         (block): Sequential(
#           3.98 M, 7.345% Params, 157.09 MMac, 2.893% MACs,
#           (0): Conv2dNormActivation(
#             1.58 M, 2.917% Params, 77.37 MMac, 1.425% MACs,
#             (0): Conv2d(1.57 M, 2.905% Params, 77.07 MMac, 1.419% MACs, 512, 3072, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(6.14 k, 0.011% Params, 301.06 KMac, 0.006% MACs, 3072, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             33.79 k, 0.062% Params, 1.66 MMac, 0.030% MACs,
#             (0): Conv2d(27.65 k, 0.051% Params, 1.35 MMac, 0.025% MACs, 3072, 3072, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=3072, bias=False)
#             (1): BatchNorm2d(6.14 k, 0.011% Params, 301.06 KMac, 0.006% MACs, 3072, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             789.63 k, 1.459% Params, 940.16 KMac, 0.017% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 150.53 KMac, 0.003% MACs, output_size=1)
#             (fc1): Conv2d(393.34 k, 0.727% Params, 393.34 KMac, 0.007% MACs, 3072, 128, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(396.29 k, 0.732% Params, 396.29 KMac, 0.007% MACs, 128, 3072, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             1.57 M, 2.907% Params, 77.12 MMac, 1.420% MACs,
#             (0): Conv2d(1.57 M, 2.905% Params, 77.07 MMac, 1.419% MACs, 3072, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1.02 k, 0.002% Params, 50.18 KMac, 0.001% MACs, 512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.19649122807017547, mode=row)
#       )
#     )
#     (8): Conv2dNormActivation(
#       657.92 k, 1.215% Params, 32.24 MMac, 0.594% MACs,
#       (0): Conv2d(655.36 k, 1.211% Params, 32.11 MMac, 0.591% MACs, 512, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(2.56 k, 0.005% Params, 125.44 KMac, 0.002% MACs, 1280, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 62.72 KMac, 0.001% MACs, output_size=1)
#   (classifier): Sequential(
#     1.28 M, 2.366% Params, 1.28 MMac, 0.024% MACs,
#     (0): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.3, inplace=True)
#     (1): Linear(1.28 M, 2.366% Params, 1.28 MMac, 0.024% MACs, in_features=1280, out_features=1000, bias=True)
#   )
# )
# Computational complexity:       5.43 GMac
# Number of parameters:           54.14 M
